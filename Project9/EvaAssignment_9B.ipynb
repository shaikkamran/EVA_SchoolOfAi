# %%
from keras import backend as K
import time
import matplotlib.pyplot as plt
import numpy as np
% matplotlib inline
np.random.seed(2017) 
from keras.models import Sequential
from keras.layers.convolutional import Convolution2D, MaxPooling2D
from keras.layers import Activation, Flatten, Dense, Dropout
from keras.layers.normalization import BatchNormalization
from keras.utils import np_utils
# Out:
# Using TensorFlow backend.

# %%
from keras.datasets import cifar10
(train_features, train_labels), (test_features, test_labels) = cifar10.load_data()
num_train, img_channels, img_rows, img_cols =  train_features.shape
num_test, _, _, _ =  test_features.shape
num_classes = len(np.unique(train_labels))
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 2s 0us/step

# %%
class_names = ['airplane','automobile','bird','cat','deer',
               'dog','frog','horse','ship','truck']
fig = plt.figure(figsize=(8,3))
for i in range(num_classes):
    ax = fig.add_subplot(2, 5, 1 + i, xticks=[], yticks=[])
    idx = np.where(train_labels[:]==i)[0]
    features_idx = train_features[idx,::]
    img_num = np.random.randint(features_idx.shape[0])
    im = features_idx[img_num]
    ax.set_title(class_names[i])
    plt.imshow(im)
plt.show()

# %%
train_features.shape
# Out:
# (50000, 32, 32, 3)

# %%
def plot_model_history(model_history):
    fig, axs = plt.subplots(1,2,figsize=(15,5))
    # summarize history for accuracy
    axs[0].plot(range(1,len(model_history.history['acc'])+1),model_history.history['acc'])
    axs[0].plot(range(1,len(model_history.history['val_acc'])+1),model_history.history['val_acc'])
    axs[0].set_title('Model Accuracy')
    axs[0].set_ylabel('Accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].set_xticks(np.arange(1,len(model_history.history['acc'])+1),len(model_history.history['acc'])/10)
    axs[0].legend(['train', 'val'], loc='best')
    # summarize history for loss
    axs[1].plot(range(1,len(model_history.history['loss'])+1),model_history.history['loss'])
    axs[1].plot(range(1,len(model_history.history['val_loss'])+1),model_history.history['val_loss'])
    axs[1].set_title('Model Loss')
    axs[1].set_ylabel('Loss')
    axs[1].set_xlabel('Epoch')
    axs[1].set_xticks(np.arange(1,len(model_history.history['loss'])+1),len(model_history.history['loss'])/10)
    axs[1].legend(['train', 'val'], loc='best')
    plt.show()

# %%
def accuracy(test_x, test_y, model):
    result = model.predict(test_x)
    predicted_class = np.argmax(result, axis=1)
    true_class = np.argmax(test_y, axis=1)
    num_correct = np.sum(predicted_class == true_class) 
    accuracy = float(num_correct)/result.shape[0]
    return (accuracy * 100)

# %%
train_features = train_features.astype('float32')/255
test_features = test_features.astype('float32')/255
# convert class labels to binary class labels
train_labels = np_utils.to_categorical(train_labels, num_classes)
test_labels = np_utils.to_categorical(test_labels, num_classes)

# %% [markdown]
# ## Fully connected layer model

# %%
# Define the model
model = Sequential()
model.add(Convolution2D(48, 3, 3, border_mode='same', input_shape=(32, 32, 3)))
model.add(Activation('relu'))
model.add(Convolution2D(48, 3, 3))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Convolution2D(96, 3, 3, border_mode='same'))
model.add(Activation('relu'))
model.add(Convolution2D(96, 3, 3))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Convolution2D(192, 3, 3, border_mode='same'))
model.add(Activation('relu'))
model.add(Convolution2D(192, 3, 3))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(256))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))
# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(48, (3, 3), input_shape=(32, 32, 3..., padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(48, (3, 3))`
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(96, (3, 3), padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(96, (3, 3))`
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:14: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(192, (3, 3), padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(192, (3, 3))`
#   app.launch_new_instance()

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_37 (Conv2D)           (None, 32, 32, 48)        1344
# _________________________________________________________________
# activation_19 (Activation)   (None, 32, 32, 48)        0
# _________________________________________________________________
# conv2d_38 (Conv2D)           (None, 30, 30, 48)        20784
# _________________________________________________________________
# activation_20 (Activation)   (None, 30, 30, 48)        0
# _________________________________________________________________
# max_pooling2d_11 (MaxPooling (None, 15, 15, 48)        0
# _________________________________________________________________
# dropout_29 (Dropout)         (None, 15, 15, 48)        0
# _________________________________________________________________
# conv2d_39 (Conv2D)           (None, 15, 15, 96)        41568
# _________________________________________________________________
# activation_21 (Activation)   (None, 15, 15, 96)        0
# _________________________________________________________________
# conv2d_40 (Conv2D)           (None, 13, 13, 96)        83040
# _________________________________________________________________
# activation_22 (Activation)   (None, 13, 13, 96)        0
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 6, 6, 96)          0
# _________________________________________________________________
# dropout_30 (Dropout)         (None, 6, 6, 96)          0
# _________________________________________________________________
# conv2d_41 (Conv2D)           (None, 6, 6, 192)         166080
# _________________________________________________________________
# activation_23 (Activation)   (None, 6, 6, 192)         0
# _________________________________________________________________
# conv2d_42 (Conv2D)           (None, 4, 4, 192)         331968
# _________________________________________________________________
# activation_24 (Activation)   (None, 4, 4, 192)         0
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 2, 2, 192)         0
# _________________________________________________________________
# dropout_31 (Dropout)         (None, 2, 2, 192)         0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 768)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 512)               393728
# _________________________________________________________________
# activation_25 (Activation)   (None, 512)               0
# _________________________________________________________________
# dropout_32 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 256)               131328
# _________________________________________________________________
# activation_26 (Activation)   (None, 256)               0
# _________________________________________________________________
# dropout_33 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 1,172,410
# Trainable params: 1,172,410
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint
filepath="Best_weights.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')

from keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(zoom_range=0.0, 
                             horizontal_flip=False)


# train the model
start = time.time()
# Train the model
model_info = model.fit_generator(datagen.flow(train_features, train_labels, batch_size = 128),
                                 samples_per_epoch = train_features.shape[0], nb_epoch = 100, 
                                 validation_data = (test_features, test_labels),callbacks=[checkpoint], verbose=1)
end = time.time()
print ("Model took %0.2f seconds to train"%(end - start))
# plot model history
plot_model_history(model_info)
# compute test accuracy
print ("Accuracy on test data is: %0.2f"%accuracy(test_features, test_labels, model))

# %%
from keras.layers import *

# %% [markdown]
# ## Optimized version of the previous Model with proper transition blocks and and proper use of dropout and l2 regularizer  with the parameter constraint of 455626 << 1.7M

# %%
def ConvReluBn(model,size=32,kernelSize=(3,3),dout=0):
  
  model.add(Convolution2D(size, kernel_size=kernelSize,border_mode='same',kernel_regularizer=regularizers.l2(0.0001),activation='relu'))
  model.add(BatchNormalization())
  model.add(Dropout(dout))
  return model

# %%
model = Sequential()

model.add(Convolution2D(32, 3, 3, border_mode='same', activation='relu',input_shape=(32, 32, 3)))
model.add(BatchNormalization())
model=ConvReluBn(model,size=64,dout=0.25)



model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.3))
model=ConvReluBn(model,size=32,kernelSize=(1,1))


model=ConvReluBn(model,size=64,dout=0.25)
model=ConvReluBn(model,size=128,dout=0.25)


model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.3))
model=ConvReluBn(model,size=32,kernelSize=(1,1))


model=ConvReluBn(model,size=128,dout=0.25)
model=ConvReluBn(model,size=256,dout=0.3)


model.add(Convolution2D(10, 1,1))

model.add(GlobalAveragePooling2D())



model.add(Activation('softmax'))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), activation="relu", input_shape=(32, 32, 3..., padding="same")`
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, kernel_size=(3, 3), kernel_regularizer=<keras.reg..., activation="relu", padding="same")`
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, kernel_size=(1, 1), kernel_regularizer=<keras.reg..., activation="relu", padding="same")`
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, kernel_size=(3, 3), kernel_regularizer=<keras.reg..., activation="relu", padding="same")`
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, kernel_size=(3, 3), kernel_regularizer=<keras.reg..., activation="relu", padding="same")`
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:28: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(10, (1, 1))`

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_135 (Conv2D)          (None, 32, 32, 32)        896
# _________________________________________________________________
# batch_normalization_96 (Batc (None, 32, 32, 32)        128
# _________________________________________________________________
# conv2d_136 (Conv2D)          (None, 32, 32, 64)        18496
# _________________________________________________________________
# batch_normalization_97 (Batc (None, 32, 32, 64)        256
# _________________________________________________________________
# dropout_100 (Dropout)        (None, 32, 32, 64)        0
# _________________________________________________________________
# max_pooling2d_30 (MaxPooling (None, 16, 16, 64)        0
# _________________________________________________________________
# dropout_101 (Dropout)        (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_137 (Conv2D)          (None, 16, 16, 32)        2080
# _________________________________________________________________
# batch_normalization_98 (Batc (None, 16, 16, 32)        128
# _________________________________________________________________
# dropout_102 (Dropout)        (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_138 (Conv2D)          (None, 16, 16, 64)        18496
# _________________________________________________________________
# batch_normalization_99 (Batc (None, 16, 16, 64)        256
# _________________________________________________________________
# dropout_103 (Dropout)        (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_139 (Conv2D)          (None, 16, 16, 128)       73856
# _________________________________________________________________
# batch_normalization_100 (Bat (None, 16, 16, 128)       512
# _________________________________________________________________
# dropout_104 (Dropout)        (None, 16, 16, 128)       0
# _________________________________________________________________
# max_pooling2d_31 (MaxPooling (None, 8, 8, 128)         0
# _________________________________________________________________
# dropout_105 (Dropout)        (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_140 (Conv2D)          (None, 8, 8, 32)          4128
# _________________________________________________________________
# batch_normalization_101 (Bat (None, 8, 8, 32)          128
# _________________________________________________________________
# dropout_106 (Dropout)        (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_141 (Conv2D)          (None, 8, 8, 128)         36992
# _________________________________________________________________
# batch_normalization_102 (Bat (None, 8, 8, 128)         512
# _________________________________________________________________
# dropout_107 (Dropout)        (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_142 (Conv2D)          (None, 8, 8, 256)         295168
# _________________________________________________________________
# batch_normalization_103 (Bat (None, 8, 8, 256)         1024
# _________________________________________________________________
# dropout_108 (Dropout)        (None, 8, 8, 256)         0
# _________________________________________________________________
# conv2d_143 (Conv2D)          (None, 8, 8, 10)          2570
# _________________________________________________________________
# global_average_pooling2d_12  (None, 10)                0
# _________________________________________________________________
# activation_17 (Activation)   (None, 10)                0
# =================================================================
# Total params: 455,626
# Trainable params: 454,154
# Non-trainable params: 1,472
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint
filepath="Best_weights.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')

from keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(zoom_range=0.0, 
                             horizontal_flip=False)


# train the model
start = time.time()
# Train the model
model_info = model.fit_generator(datagen.flow(train_features, train_labels, batch_size = 128),
                                 samples_per_epoch = train_features.shape[0], nb_epoch = 10, 
                                 validation_data = (test_features, test_labels),callbacks=[checkpoint], verbose=1)
end = time.time()
print ("Model took %0.2f seconds to train"%(end - start))
# plot model history
plot_model_history(model_info)
# compute test accuracy
print ("Accuracy on test data is: %0.2f"%accuracy(test_features, test_labels, model))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
#   app.launch_new_instance()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras_pre..., validation_data=(array([[[..., callbacks=[<keras.ca..., verbose=1, steps_per_epoch=390, epochs=10)`
#   app.launch_new_instance()
# Epoch 1/10
# 390/390 [==============================] - 44s 113ms/step - loss: 1.4209 - acc: 0.5009 - val_loss: 1.3621 - val_acc: 0.5520
#
# Epoch 00001: val_acc improved from -inf to 0.55200, saving model to Best_weights.hdf5
# Epoch 2/10
# 390/390 [==============================] - 37s 95ms/step - loss: 1.0556 - acc: 0.6426 - val_loss: 1.0146 - val_acc: 0.6657
#
# Epoch 00002: val_acc improved from 0.55200 to 0.66570, saving model to Best_weights.hdf5
# Epoch 3/10
# 390/390 [==============================] - 37s 95ms/step - loss: 0.9195 - acc: 0.6954 - val_loss: 1.0711 - val_acc: 0.6466
#
# Epoch 00003: val_acc did not improve from 0.66570
# Epoch 4/10
# 390/390 [==============================] - 37s 95ms/step - loss: 0.8308 - acc: 0.7298 - val_loss: 0.8197 - val_acc: 0.7351
#
# Epoch 00004: val_acc improved from 0.66570 to 0.73510, saving model to Best_weights.hdf5
# Epoch 5/10
# 390/390 [==============================] - 37s 95ms/step - loss: 0.7627 - acc: 0.7569 - val_loss: 0.8415 - val_acc: 0.7329
#
# Epoch 00005: val_acc did not improve from 0.73510
# Epoch 6/10
# 390/390 [==============================] - 37s 95ms/step - loss: 0.7182 - acc: 0.7756 - val_loss: 0.7486 - val_acc: 0.7686
#
# Epoch 00006: val_acc improved from 0.73510 to 0.76860, saving model to Best_weights.hdf5
# Epoch 7/10
# 390/390 [==============================] - 37s 94ms/step - loss: 0.6821 - acc: 0.7931 - val_loss: 0.8073 - val_acc: 0.7545
#
# Epoch 00007: val_acc did not improve from 0.76860
# Epoch 8/10
# 390/390 [==============================] - 37s 95ms/step - loss: 0.6522 - acc: 0.8020 - val_loss: 0.7558 - val_acc: 0.7723
#
# Epoch 00008: val_acc improved from 0.76860 to 0.77230, saving model to Best_weights.hdf5
# Epoch 9/10
# 390/390 [==============================] - 37s 95ms/step - loss: 0.6338 - acc: 0.8097 - val_loss: 0.6686 - val_acc: 0.8050
#
# Epoch 00009: val_acc improved from 0.77230 to 0.80500, saving model to Best_weights.hdf5
# Epoch 10/10
# 390/390 [==============================] - 37s 95ms/step - loss: 0.6137 - acc: 0.8208 - val_loss: 0.7160 - val_acc: 0.7843
#
# Epoch 00010: val_acc did not improve from 0.80500
# Model took 390.73 seconds to train
# Accuracy on test data is: 78.43

# %%
# model=Model()
# model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])


# from keras.callbacks import ModelCheckpoint
# filepath="Best_weights.hdf5"
# checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')

# from keras.preprocessing.image import ImageDataGenerator

# datagen = ImageDataGenerator(featurewise_center=True, featurewise_std_normalization=True,zoom_range=0.0, 
#                              horizontal_flip=False)


# # train the model
start = time.time()
# Train the model
model_info = model.fit_generator(datagen.flow(train_features, train_labels, batch_size = 128),
                                 samples_per_epoch = train_features.shape[0], nb_epoch = 90, 
                                 validation_data = (test_features, test_labels),callbacks=[checkpoint], verbose=1)
end = time.time()
print ("Model took %0.2f seconds to train"%(end - start))
# plot model history
plot_model_history(model_info)
# compute test accuracy
print ("Accuracy on test data is: %0.2f"%accuracy(test_features, test_labels, model))
# Out:
# Epoch 1/90
#   1/390 [..............................] - ETA: 45s - loss: 0.5497 - acc: 0.8281
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
#   """
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras_pre..., validation_data=(array([[[..., callbacks=[<keras.ca..., verbose=1, steps_per_epoch=390, epochs=90)`
#   """
# 390/390 [==============================] - 37s 95ms/step - loss: 0.5973 - acc: 0.8273 - val_loss: 0.7947 - val_acc: 0.7716
#
# Epoch 00001: val_acc did not improve from 0.80500
# Epoch 2/90
# 390/390 [==============================] - 37s 95ms/step - loss: 0.5811 - acc: 0.8349 - val_loss: 0.8804 - val_acc: 0.7528
#
# Epoch 00002: val_acc did not improve from 0.80500
# Epoch 3/90
# 390/390 [==============================] - 37s 95ms/step - loss: 0.5713 - acc: 0.8395 - val_loss: 0.9357 - val_acc: 0.7326
#
# Epoch 00003: val_acc did not improve from 0.80500
# Epoch 4/90
# 390/390 [==============================] - 37s 95ms/step - loss: 0.5599 - acc: 0.8454 - val_loss: 0.6846 - val_acc: 0.8068
#
# Epoch 00004: val_acc improved from 0.80500 to 0.80680, saving model to Best_weights.hdf5
# Epoch 5/90
# 390/390 [==============================] - 37s 95ms/step - loss: 0.5463 - acc: 0.8499 - val_loss: 0.8021 - val_acc: 0.7662
#
# Epoch 00005: val_acc did not improve from 0.80680
# Epoch 6/90
# 390/390 [==============================] - 37s 95ms/step - loss: 0.5462 - acc: 0.8513 - val_loss: 0.6465 - val_acc: 0.8221
#
# Epoch 00006: val_acc improved from 0.80680 to 0.82210, saving model to Best_weights.hdf5
# Epoch 7/90
# 390/390 [==============================] - 37s 95ms/step - loss: 0.5410 - acc: 0.8542 - val_loss: 0.7272 - val_acc: 0.7984
#
# Epoch 00007: val_acc did not improve from 0.82210
# Epoch 8/90
# 390/390 [==============================] - 37s 95ms/step - loss: 0.5280 - acc: 0.8582 - val_loss: 0.6466 - val_acc: 0.8198
#
# Epoch 00008: val_acc did not improve from 0.82210
# Epoch 9/90
# 390/390 [==============================] - 37s 95ms/step - loss: 0.5266 - acc: 0.8605 - val_loss: 0.7148 - val_acc: 0.8048
#
# Epoch 00009: val_acc did not improve from 0.82210
# Epoch 10/90
# 390/390 [==============================] - 37s 95ms/step - loss: 0.5171 - acc: 0.8654 - val_loss: 0.6816 - val_acc: 0.8107
#
# Epoch 00010: val_acc did not improve from 0.82210
# Epoch 11/90
# 390/390 [==============================] - 37s 95ms/step - loss: 0.5062 - acc: 0.8713 - val_loss: 0.6871 - val_acc: 0.8079
#
# Epoch 00011: val_acc did not improve from 0.82210
# Epoch 12/90
# 390/390 [==============================] - 37s 95ms/step - loss: 0.5067 - acc: 0.8728 - val_loss: 0.6552 - val_acc: 0.8278
#
# Epoch 00012: val_acc improved from 0.82210 to 0.82780, saving model to Best_weights.hdf5
# Epoch 13/90
# 390/390 [==============================] - 37s 95ms/step - loss: 0.4995 - acc: 0.8736 - val_loss: 0.6500 - val_acc: 0.8280
#
# Epoch 00013: val_acc improved from 0.82780 to 0.82800, saving model to Best_weights.hdf5
# Epoch 14/90
# 390/390 [==============================] - 37s 95ms/step - loss: 0.5003 - acc: 0.8743 - val_loss: 0.6931 - val_acc: 0.8115
#
# Epoch 00014: val_acc did not improve from 0.82800
# Epoch 15/90
# 390/390 [==============================] - 37s 95ms/step - loss: 0.4970 - acc: 0.8765 - val_loss: 0.7087 - val_acc: 0.8084
#
# Epoch 00015: val_acc did not improve from 0.82800
# Epoch 16/90
# 390/390 [==============================] - 37s 95ms/step - loss: 0.4865 - acc: 0.8806 - val_loss: 0.7479 - val_acc: 0.8046
#
# Epoch 00016: val_acc did not improve from 0.82800
# Epoch 17/90
# 390/390 [==============================] - 37s 94ms/step - loss: 0.4917 - acc: 0.8804 - val_loss: 0.6664 - val_acc: 0.8323
#
# Epoch 00017: val_acc improved from 0.82800 to 0.83230, saving model to Best_weights.hdf5
# Epoch 18/90
# 390/390 [==============================] - 37s 95ms/step - loss: 0.4858 - acc: 0.8828 - val_loss: 0.7111 - val_acc: 0.8171
#
# Epoch 00018: val_acc did not improve from 0.83230
# Epoch 19/90
# 390/390 [==============================] - 37s 95ms/step - loss: 0.4810 - acc: 0.8843 - val_loss: 0.6295 - val_acc: 0.8436
#
# Epoch 00019: val_acc improved from 0.83230 to 0.84360, saving model to Best_weights.hdf5
# Epoch 20/90
# 390/390 [==============================] - 37s 95ms/step - loss: 0.4838 - acc: 0.8845 - val_loss: 0.6437 - val_acc: 0.8344
#
# Epoch 00020: val_acc did not improve from 0.84360
# Epoch 21/90
# 390/390 [==============================] - 37s 95ms/step - loss: 0.4801 - acc: 0.8853 - val_loss: 0.6817 - val_acc: 0.8266
#
# Epoch 00021: val_acc did not improve from 0.84360
# Epoch 22/90
# 390/390 [==============================] - 37s 95ms/step - loss: 0.4723 - acc: 0.8888 - val_loss: 0.7197 - val_acc: 0.8208
#
# Epoch 00022: val_acc did not improve from 0.84360
# Epoch 23/90
# 390/390 [==============================] - 37s 95ms/step - loss: 0.4726 - acc: 0.8904 - val_loss: 0.6431 - val_acc: 0.8396
#
# Epoch 00023: val_acc did not improve from 0.84360
# Epoch 24/90
# 390/390 [==============================] - 37s 95ms/step - loss: 0.4701 - acc: 0.8907 - val_loss: 0.7785 - val_acc: 0.7978
#
# Epoch 00024: val_acc did not improve from 0.84360
# Epoch 25/90
# 390/390 [==============================] - 37s 95ms/step - loss: 0.4663 - acc: 0.8927 - val_loss: 0.6207 - val_acc: 0.8458
#
# Epoch 00025: val_acc improved from 0.84360 to 0.84580, saving model to Best_weights.hdf5
# Epoch 26/90
# 390/390 [==============================] - 37s 94ms/step - loss: 0.4693 - acc: 0.8907 - val_loss: 0.7658 - val_acc: 0.8055
#
# Epoch 00026: val_acc did not improve from 0.84580
# Epoch 27/90
# 390/390 [==============================] - 37s 94ms/step - loss: 0.4671 - acc: 0.8931 - val_loss: 0.6541 - val_acc: 0.8411
#
# Epoch 00027: val_acc did not improve from 0.84580
# Epoch 28/90
# 390/390 [==============================] - 37s 95ms/step - loss: 0.4612 - acc: 0.8960 - val_loss: 0.6234 - val_acc: 0.8494
#
# Epoch 00028: val_acc improved from 0.84580 to 0.84940, saving model to Best_weights.hdf5
# Epoch 29/90
# 390/390 [==============================] - 37s 95ms/step - loss: 0.4628 - acc: 0.8968 - val_loss: 0.7185 - val_acc: 0.8176
#
# Epoch 00029: val_acc did not improve from 0.84940
# Epoch 30/90
# 390/390 [==============================] - 37s 95ms/step - loss: 0.4646 - acc: 0.8965 - val_loss: 0.6387 - val_acc: 0.8438
#
# Epoch 00030: val_acc did not improve from 0.84940
# Epoch 31/90
# 390/390 [==============================] - 37s 95ms/step - loss: 0.4609 - acc: 0.8958 - val_loss: 0.6640 - val_acc: 0.8330
#
# Epoch 00031: val_acc did not improve from 0.84940
# Epoch 32/90
# 390/390 [==============================] - 37s 95ms/step - loss: 0.4590 - acc: 0.8972 - val_loss: 0.6530 - val_acc: 0.8452
#
# Epoch 00032: val_acc did not improve from 0.84940
# Epoch 33/90
# 390/390 [==============================] - 37s 95ms/step - loss: 0.4579 - acc: 0.8979 - val_loss: 0.6796 - val_acc: 0.8329
#
# Epoch 00033: val_acc did not improve from 0.84940
# Epoch 34/90
# 390/390 [==============================] - 37s 94ms/step - loss: 0.4559 - acc: 0.9002 - val_loss: 0.7005 - val_acc: 0.8223
#
# Epoch 00034: val_acc did not improve from 0.84940
# Epoch 35/90
# 390/390 [==============================] - 37s 95ms/step - loss: 0.4549 - acc: 0.8994 - val_loss: 0.6865 - val_acc: 0.8336
#
# Epoch 00035: val_acc did not improve from 0.84940
# Epoch 36/90
# 390/390 [==============================] - 37s 95ms/step - loss: 0.4535 - acc: 0.9008 - val_loss: 0.6867 - val_acc: 0.8351
#
# Epoch 00036: val_acc did not improve from 0.84940
# Epoch 37/90
# 390/390 [==============================] - 37s 95ms/step - loss: 0.4522 - acc: 0.9020 - val_loss: 0.6747 - val_acc: 0.8326
#
# Epoch 00037: val_acc did not improve from 0.84940
# Epoch 38/90
# 390/390 [==============================] - 37s 94ms/step - loss: 0.4490 - acc: 0.9033 - val_loss: 0.6788 - val_acc: 0.8372
#
# Epoch 00038: val_acc did not improve from 0.84940
# Epoch 39/90
# 390/390 [==============================] - 37s 95ms/step - loss: 0.4520 - acc: 0.9021 - val_loss: 0.7729 - val_acc: 0.8176
#
# Epoch 00039: val_acc did not improve from 0.84940
# Epoch 40/90
# 390/390 [==============================] - 37s 95ms/step - loss: 0.4537 - acc: 0.9012 - val_loss: 0.6315 - val_acc: 0.8476
#
# Epoch 00040: val_acc did not improve from 0.84940
# Epoch 41/90
# 390/390 [==============================] - 37s 95ms/step - loss: 0.4514 - acc: 0.9026 - val_loss: 0.7304 - val_acc: 0.8173
#
# Epoch 00041: val_acc did not improve from 0.84940
# Epoch 42/90
# 390/390 [==============================] - 37s 95ms/step - loss: 0.4463 - acc: 0.9040 - val_loss: 0.6880 - val_acc: 0.8316
#
# Epoch 00042: val_acc did not improve from 0.84940
# Epoch 43/90
# 390/390 [==============================] - 37s 95ms/step - loss: 0.4476 - acc: 0.9048 - val_loss: 0.6877 - val_acc: 0.8373
#
# Epoch 00043: val_acc did not improve from 0.84940
# Epoch 44/90
# 390/390 [==============================] - 37s 94ms/step - loss: 0.4560 - acc: 0.9021 - val_loss: 0.6856 - val_acc: 0.8359
#
# Epoch 00044: val_acc did not improve from 0.84940
# Epoch 45/90
# 390/390 [==============================] - 37s 95ms/step - loss: 0.4441 - acc: 0.9065 - val_loss: 0.6623 - val_acc: 0.8466
#
# Epoch 00045: val_acc did not improve from 0.84940
# Epoch 46/90
# 390/390 [==============================] - 37s 95ms/step - loss: 0.4390 - acc: 0.9076 - val_loss: 0.7219 - val_acc: 0.8240
#
# Epoch 00046: val_acc did not improve from 0.84940
# Epoch 47/90
# 390/390 [==============================] - 37s 95ms/step - loss: 0.4470 - acc: 0.9070 - val_loss: 0.7276 - val_acc: 0.8262
#
# Epoch 00047: val_acc did not improve from 0.84940
# Epoch 48/90
# 390/390 [==============================] - 37s 94ms/step - loss: 0.4379 - acc: 0.9091 - val_loss: 0.6050 - val_acc: 0.8620
#
# Epoch 00048: val_acc improved from 0.84940 to 0.86200, saving model to Best_weights.hdf5
# Epoch 49/90
# 390/390 [==============================] - 37s 94ms/step - loss: 0.4471 - acc: 0.9060 - val_loss: 0.6765 - val_acc: 0.8434
#
# Epoch 00049: val_acc did not improve from 0.86200
# Epoch 50/90
# 390/390 [==============================] - 37s 95ms/step - loss: 0.4390 - acc: 0.9095 - val_loss: 0.6143 - val_acc: 0.8607
#
# Epoch 00050: val_acc did not improve from 0.86200
# Epoch 51/90
# 390/390 [==============================] - 37s 95ms/step - loss: 0.4430 - acc: 0.9080 - val_loss: 0.6170 - val_acc: 0.8563
#
# Epoch 00051: val_acc did not improve from 0.86200
# Epoch 52/90
# 390/390 [==============================] - 37s 95ms/step - loss: 0.4417 - acc: 0.9080 - val_loss: 0.6529 - val_acc: 0.8477
#
# Epoch 00052: val_acc did not improve from 0.86200
# Epoch 53/90
# 390/390 [==============================] - 37s 95ms/step - loss: 0.4364 - acc: 0.9114 - val_loss: 0.6476 - val_acc: 0.8539
#
# Epoch 00053: val_acc did not improve from 0.86200
# Epoch 54/90
# 390/390 [==============================] - 37s 94ms/step - loss: 0.4390 - acc: 0.9092 - val_loss: 0.6337 - val_acc: 0.8526
#
# Epoch 00054: val_acc did not improve from 0.86200
# Epoch 55/90
# 390/390 [==============================] - 37s 95ms/step - loss: 0.4422 - acc: 0.9078 - val_loss: 0.7113 - val_acc: 0.8349
#
# Epoch 00055: val_acc did not improve from 0.86200
# Epoch 56/90
# 390/390 [==============================] - 37s 95ms/step - loss: 0.4377 - acc: 0.9114 - val_loss: 0.7026 - val_acc: 0.8350
#
# Epoch 00056: val_acc did not improve from 0.86200
# Epoch 57/90
# 390/390 [==============================] - 37s 95ms/step - loss: 0.4347 - acc: 0.9107 - val_loss: 0.7055 - val_acc: 0.8328
#
# Epoch 00057: val_acc did not improve from 0.86200
# Epoch 58/90
# 390/390 [==============================] - 37s 94ms/step - loss: 0.4346 - acc: 0.9117 - val_loss: 0.6611 - val_acc: 0.8523
#
# Epoch 00058: val_acc did not improve from 0.86200
# Epoch 59/90
# 390/390 [==============================] - 37s 95ms/step - loss: 0.4369 - acc: 0.9111 - val_loss: 0.6368 - val_acc: 0.8575
#
# Epoch 00059: val_acc did not improve from 0.86200
# Epoch 60/90
# 390/390 [==============================] - 37s 95ms/step - loss: 0.4367 - acc: 0.9118 - val_loss: 0.6712 - val_acc: 0.8463
#
# Epoch 00060: val_acc did not improve from 0.86200
# Epoch 61/90
# 390/390 [==============================] - 37s 95ms/step - loss: 0.4366 - acc: 0.9112 - val_loss: 0.6580 - val_acc: 0.8437
#
# Epoch 00061: val_acc did not improve from 0.86200
# Epoch 62/90
# 390/390 [==============================] - 37s 95ms/step - loss: 0.4281 - acc: 0.9144 - val_loss: 0.7566 - val_acc: 0.8237
#
# Epoch 00062: val_acc did not improve from 0.86200
# Epoch 63/90
# 390/390 [==============================] - 37s 94ms/step - loss: 0.4326 - acc: 0.9131 - val_loss: 0.6657 - val_acc: 0.8460
#
# Epoch 00063: val_acc did not improve from 0.86200
# Epoch 64/90
# 390/390 [==============================] - 37s 95ms/step - loss: 0.4337 - acc: 0.9134 - val_loss: 0.7013 - val_acc: 0.8386
#
# Epoch 00064: val_acc did not improve from 0.86200
# Epoch 65/90
# 390/390 [==============================] - 37s 95ms/step - loss: 0.4331 - acc: 0.9124 - val_loss: 0.6698 - val_acc: 0.8470
#
# Epoch 00065: val_acc did not improve from 0.86200
# Epoch 66/90
# 390/390 [==============================] - 37s 95ms/step - loss: 0.4398 - acc: 0.9115 - val_loss: 0.6918 - val_acc: 0.8456
#
# Epoch 00066: val_acc did not improve from 0.86200
# Epoch 67/90
# 390/390 [==============================] - 37s 95ms/step - loss: 0.4267 - acc: 0.9152 - val_loss: 0.6549 - val_acc: 0.8541
#
# Epoch 00067: val_acc did not improve from 0.86200
# Epoch 68/90
# 390/390 [==============================] - 37s 95ms/step - loss: 0.4364 - acc: 0.9128 - val_loss: 0.6862 - val_acc: 0.8426
#
# Epoch 00068: val_acc did not improve from 0.86200
# Epoch 69/90
# 390/390 [==============================] - 37s 95ms/step - loss: 0.4327 - acc: 0.9148 - val_loss: 0.6806 - val_acc: 0.8463
#
# Epoch 00069: val_acc did not improve from 0.86200
# Epoch 70/90
# 390/390 [==============================] - 37s 95ms/step - loss: 0.4361 - acc: 0.9134 - val_loss: 0.8083 - val_acc: 0.8068
#
# Epoch 00070: val_acc did not improve from 0.86200
# Epoch 71/90
# 390/390 [==============================] - 37s 94ms/step - loss: 0.4314 - acc: 0.9136 - val_loss: 0.6760 - val_acc: 0.8468
#
# Epoch 00071: val_acc did not improve from 0.86200
# Epoch 72/90
# 390/390 [==============================] - 37s 95ms/step - loss: 0.4292 - acc: 0.9156 - val_loss: 0.6803 - val_acc: 0.8496
#
# Epoch 00072: val_acc did not improve from 0.86200
# Epoch 73/90
# 390/390 [==============================] - 37s 94ms/step - loss: 0.4248 - acc: 0.9164 - val_loss: 0.6881 - val_acc: 0.8395
#
# Epoch 00073: val_acc did not improve from 0.86200
# Epoch 74/90
# 390/390 [==============================] - 37s 94ms/step - loss: 0.4277 - acc: 0.9142 - val_loss: 0.6942 - val_acc: 0.8389
#
# Epoch 00074: val_acc did not improve from 0.86200
# Epoch 75/90
# 390/390 [==============================] - 37s 95ms/step - loss: 0.4294 - acc: 0.9151 - val_loss: 0.7623 - val_acc: 0.8296
#
# Epoch 00075: val_acc did not improve from 0.86200
# Epoch 76/90
# 390/390 [==============================] - 37s 94ms/step - loss: 0.4299 - acc: 0.9169 - val_loss: 0.7318 - val_acc: 0.8331
#
# Epoch 00076: val_acc did not improve from 0.86200
# Epoch 77/90
# 390/390 [==============================] - 37s 94ms/step - loss: 0.4290 - acc: 0.9168 - val_loss: 0.6910 - val_acc: 0.8422
#
# Epoch 00077: val_acc did not improve from 0.86200
# Epoch 78/90
# 390/390 [==============================] - 37s 94ms/step - loss: 0.4233 - acc: 0.9189 - val_loss: 0.7581 - val_acc: 0.8269
#
# Epoch 00078: val_acc did not improve from 0.86200
# Epoch 79/90
# 390/390 [==============================] - 37s 95ms/step - loss: 0.4262 - acc: 0.9161 - val_loss: 0.6689 - val_acc: 0.8491
#
# Epoch 00079: val_acc did not improve from 0.86200
# Epoch 80/90
# 390/390 [==============================] - 37s 95ms/step - loss: 0.4266 - acc: 0.9181 - val_loss: 0.6610 - val_acc: 0.8527
#
# Epoch 00080: val_acc did not improve from 0.86200
# Epoch 81/90
# 390/390 [==============================] - 37s 95ms/step - loss: 0.4273 - acc: 0.9170 - val_loss: 0.8383 - val_acc: 0.8086
#
# Epoch 00081: val_acc did not improve from 0.86200
# Epoch 82/90
# 390/390 [==============================] - 37s 95ms/step - loss: 0.4275 - acc: 0.9163 - val_loss: 0.7102 - val_acc: 0.8438
#
# Epoch 00082: val_acc did not improve from 0.86200
# Epoch 83/90
# 390/390 [==============================] - 37s 95ms/step - loss: 0.4342 - acc: 0.9145 - val_loss: 0.7041 - val_acc: 0.8348
#
# Epoch 00083: val_acc did not improve from 0.86200
# Epoch 84/90
# 390/390 [==============================] - 37s 94ms/step - loss: 0.4258 - acc: 0.9179 - val_loss: 0.6796 - val_acc: 0.8474
#
# Epoch 00084: val_acc did not improve from 0.86200
# Epoch 85/90
# 390/390 [==============================] - 37s 94ms/step - loss: 0.4209 - acc: 0.9197 - val_loss: 0.8159 - val_acc: 0.8095
#
# Epoch 00085: val_acc did not improve from 0.86200
# Epoch 86/90
# 390/390 [==============================] - 37s 94ms/step - loss: 0.4213 - acc: 0.9193 - val_loss: 0.6275 - val_acc: 0.8634
#
# Epoch 00086: val_acc improved from 0.86200 to 0.86340, saving model to Best_weights.hdf5
# Epoch 87/90
# 390/390 [==============================] - 37s 95ms/step - loss: 0.4225 - acc: 0.9175 - val_loss: 0.6751 - val_acc: 0.8460
#
# Epoch 00087: val_acc did not improve from 0.86340
# Epoch 88/90
# 390/390 [==============================] - 37s 95ms/step - loss: 0.4262 - acc: 0.9172 - val_loss: 0.6914 - val_acc: 0.8416
#
# Epoch 00088: val_acc did not improve from 0.86340
# Epoch 89/90
# 390/390 [==============================] - 37s 95ms/step - loss: 0.4199 - acc: 0.9189 - val_loss: 0.6568 - val_acc: 0.8539
#
# Epoch 00089: val_acc did not improve from 0.86340
# Epoch 90/90
# 390/390 [==============================] - 37s 95ms/step - loss: 0.4233 - acc: 0.9182 - val_loss: 0.6847 - val_acc: 0.8508
#
# Epoch 00090: val_acc did not improve from 0.86340
# Model took 3324.80 seconds to train
# Accuracy on test data is: 85.08

# %%
# !ls
# Out:
# Best_weights.hdf5  sample_data

# %% [markdown]
# ## Loading the saved Model from drive

# %%
from keras.layers import *
from keras.models import load_model

# %%
from google.colab import drive

drive.mount('/gdrive')
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %%
model_path ='''/gdrive/My Drive/EVA2019/6A_model.hdf5'''

# %%
img_path ='''/gdrive/My Drive/EVA2019/cat.jpeg'''

# %%
model=load_model(model_path)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0627 18:41:28.851874 140143747749760 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0627 18:41:28.871825 140143747749760 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0627 18:41:28.898297 140143747749760 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:245: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0627 18:41:28.899408 140143747749760 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0627 18:41:28.900367 140143747749760 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0627 18:41:29.680572 140143747749760 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# W0627 18:41:29.951902 140143747749760 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# W0627 18:41:29.965383 140143747749760 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# W0627 18:41:30.985611 140143747749760 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0627 18:41:31.168153 140143747749760 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
accuracy(test_features, test_labels, model)
# Out:
# 86.33999999999999

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_135 (Conv2D)          (None, 32, 32, 32)        896
# _________________________________________________________________
# batch_normalization_96 (Batc (None, 32, 32, 32)        128
# _________________________________________________________________
# conv2d_136 (Conv2D)          (None, 32, 32, 64)        18496
# _________________________________________________________________
# batch_normalization_97 (Batc (None, 32, 32, 64)        256
# _________________________________________________________________
# dropout_100 (Dropout)        (None, 32, 32, 64)        0
# _________________________________________________________________
# max_pooling2d_30 (MaxPooling (None, 16, 16, 64)        0
# _________________________________________________________________
# dropout_101 (Dropout)        (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_137 (Conv2D)          (None, 16, 16, 32)        2080
# _________________________________________________________________
# batch_normalization_98 (Batc (None, 16, 16, 32)        128
# _________________________________________________________________
# dropout_102 (Dropout)        (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_138 (Conv2D)          (None, 16, 16, 64)        18496
# _________________________________________________________________
# batch_normalization_99 (Batc (None, 16, 16, 64)        256
# _________________________________________________________________
# dropout_103 (Dropout)        (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_139 (Conv2D)          (None, 16, 16, 128)       73856
# _________________________________________________________________
# batch_normalization_100 (Bat (None, 16, 16, 128)       512
# _________________________________________________________________
# dropout_104 (Dropout)        (None, 16, 16, 128)       0
# _________________________________________________________________
# max_pooling2d_31 (MaxPooling (None, 8, 8, 128)         0
# _________________________________________________________________
# dropout_105 (Dropout)        (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_140 (Conv2D)          (None, 8, 8, 32)          4128
# _________________________________________________________________
# batch_normalization_101 (Bat (None, 8, 8, 32)          128
# _________________________________________________________________
# dropout_106 (Dropout)        (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_141 (Conv2D)          (None, 8, 8, 128)         36992
# _________________________________________________________________
# batch_normalization_102 (Bat (None, 8, 8, 128)         512
# _________________________________________________________________
# dropout_107 (Dropout)        (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_142 (Conv2D)          (None, 8, 8, 256)         295168
# _________________________________________________________________
# batch_normalization_103 (Bat (None, 8, 8, 256)         1024
# _________________________________________________________________
# dropout_108 (Dropout)        (None, 8, 8, 256)         0
# _________________________________________________________________
# conv2d_143 (Conv2D)          (None, 8, 8, 10)          2570
# _________________________________________________________________
# global_average_pooling2d_12  (None, 10)                0
# _________________________________________________________________
# activation_17 (Activation)   (None, 10)                0
# =================================================================
# Total params: 455,626
# Trainable params: 454,154
# Non-trainable params: 1,472
# _________________________________________________________________

# %%
im=test_features[8010]
plt.imshow(im)

img=np.array([im])
print(class_names[np.argmax(model.predict(img))])
# Out:
# bird

# %%
from keras.applications.vgg16 import VGG16, preprocess_input, decode_predictions
from keras.preprocessing import image
import keras.backend as K
import numpy as np
import cv2
import sys

# %% [markdown]
# ## Visualizing the GradCamoutput Over different layers

# %%
def visualize_GradCam(img,layer_name='conv2d_139'):


  x = img
  x = np.expand_dims(x, axis=0)
  preds = model.predict(x)
  class_idx = np.argmax(preds[0])
  class_output = model.output[:, class_idx]
  last_conv_layer = model.get_layer(layer_name)
  print(class_names[class_idx])
#   plt.imshow(img)
  grads = K.gradients(class_output, last_conv_layer.output)[0]
  pooled_grads = K.mean(grads, axis=(0, 1, 2))
  iterate = K.function([model.input], [pooled_grads, last_conv_layer.output[0]])

  pooled_grads_value, conv_layer_output_value = iterate([x])

  for i in range(conv_layer_output_value.shape[-1]):
    conv_layer_output_value[:, :, i] *= pooled_grads_value[i]

  heatmap = np.mean(conv_layer_output_value, axis=-1)
  heatmap = np.maximum(heatmap, 0)
  heatmap /= np.max(heatmap)    


  heatmap = cv2.resize(heatmap, (img.shape[1], img.shape[0]))
  
  ##Changing the range of values to [1,255] so that they can be taken in by applyColorMap function
  
  heatmap = np.uint8(255*heatmap)
  heatmap = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)
  
  ##Chnaging the range again between [0,1]
  
  heatmap=heatmap.astype('float32')/255

  superimposed_img = cv2.addWeighted(img, 0.7, heatmap, 0.3, 0)
  
  return heatmap,superimposed_img

# %%
def show_gradcam(img,layer_name='conv2d_139'):
  

  

  heatmap,superimposed_img=visualize_GradCam(img,layer_name)



  images = []
  images.append(img)
  images.append(heatmap)

  images.append(superimposed_img)

  titles = ['Original Image','HeatMap','gradCam Image']
  f = plt.figure(figsize=(15,15))

  for i in range(len(images)):
      plt.subplot(1,3,i+1),plt.imshow(images[i])
      plt.title(titles[i])
      plt.xticks([]),plt.yticks([])

  plt.show()

# %%
show_gradcam(test_features[1001],layer_name='conv2d_141')
# Out:
# airplane

# %%
show_gradcam(test_features[1101],layer_name='conv2d_139')
# Out:
# ship

# %%
show_gradcam(test_features[1111])
# Out:
# ship

# %%
show_gradcam(test_features[99])
# Out:
# horse

# %%
show_gradcam(test_features[8010])
# Out:
# bird

# %% [markdown]
# ## Retraining the above 6A model using cut-out

# %%
from keras.layers import *

# %%
model = Sequential()

model.add(Convolution2D(32, 3, 3, border_mode='same', activation='relu',input_shape=(32, 32, 3)))
model.add(BatchNormalization())
model=ConvReluBn(model,size=64,dout=0.25)



model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.3))
model=ConvReluBn(model,size=32,kernelSize=(1,1))


model=ConvReluBn(model,size=64,dout=0.25)
model=ConvReluBn(model,size=128,dout=0.25)


model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.3))
model=ConvReluBn(model,size=32,kernelSize=(1,1))


model=ConvReluBn(model,size=128,dout=0.25)
model=ConvReluBn(model,size=256,dout=0.3)


model.add(Convolution2D(10, 1,1))

model.add(GlobalAveragePooling2D())



model.add(Activation('softmax'))
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0629 19:14:29.035510 139716608444288 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), activation="relu", input_shape=(32, 32, 3..., padding="same")`
#   This is separate from the ipykernel package so we can avoid doing imports until
# W0629 19:14:29.074403 139716608444288 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0629 19:14:29.083180 139716608444288 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0629 19:14:29.121469 139716608444288 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0629 19:14:29.122706 139716608444288 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0629 19:14:31.945063 139716608444288 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1834: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, kernel_size=(3, 3), kernel_regularizer=<keras.reg..., activation="relu", padding="same")`
#   This is separate from the ipykernel package so we can avoid doing imports until
# W0629 19:14:32.241915 139716608444288 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# W0629 19:14:32.259016 139716608444288 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, kernel_size=(1, 1), kernel_regularizer=<keras.reg..., activation="relu", padding="same")`
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, kernel_size=(3, 3), kernel_regularizer=<keras.reg..., activation="relu", padding="same")`
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, kernel_size=(3, 3), kernel_regularizer=<keras.reg..., activation="relu", padding="same")`
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:27: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(10, (1, 1))`

# %%
# !git clone https://github.com/yu4u/cutout-random-erasing.git
# Out:
# Cloning into 'cutout-random-erasing'...
# remote: Enumerating objects: 23, done.
# remote: Total 23 (delta 0), reused 0 (delta 0), pack-reused 23
# Unpacking objects: 100% (23/23), done.

# %%
# !mv cutout-random-erasing/*  ./

# %%
from random_eraser import get_random_eraser


from keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# ### Visualizing Cut -out on the Training Images

# %%
# x = np.zeros((img_num, 64, 64, 3), dtype=np.uint8)

x=train_features[10:31]

eraser = get_random_eraser(v_h=1,v_l=0)

for i in range(img_num):
    plt.subplot(rows, cols, i + 1)
    plt.imshow(eraser(x[i]), interpolation="nearest")
    plt.axis('off')
# Out:
# W0629 19:56:36.924672 139716608444288 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0629 19:56:36.937403 139716608444288 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0629 19:56:36.949591 139716608444288 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0629 19:56:36.961095 139716608444288 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0629 19:56:36.973427 139716608444288 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0629 19:56:36.984599 139716608444288 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0629 19:56:36.997782 139716608444288 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0629 19:56:37.011265 139716608444288 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0629 19:56:37.023710 139716608444288 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0629 19:56:37.036439 139716608444288 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0629 19:56:37.049378 139716608444288 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0629 19:56:37.061680 139716608444288 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0629 19:56:37.073930 139716608444288 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0629 19:56:37.088845 139716608444288 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0629 19:56:37.102804 139716608444288 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0629 19:56:37.115193 139716608444288 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0629 19:56:37.127401 139716608444288 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0629 19:56:37.141617 139716608444288 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0629 19:56:37.154512 139716608444288 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# W0629 19:56:37.168322 139716608444288 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
datagen = ImageDataGenerator(zoom_range=0.0, 
                             horizontal_flip=False,

        preprocessing_function=get_random_eraser(v_l=0, v_h=1))

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# W0629 19:21:13.046477 139716608444288 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
from keras.callbacks import ModelCheckpoint
filepath="Best_weights.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')

# from keras.preprocessing.image import ImageDataGenerator

# datagen = ImageDataGenerator(zoom_range=0.0, 
#                              horizontal_flip=False)


# train the model
start = time.time()
# Train the model
model_info = model.fit_generator(datagen.flow(train_features, train_labels, batch_size = 128),
                                 samples_per_epoch = train_features.shape[0], nb_epoch = 10, 
                                 validation_data = (test_features, test_labels),callbacks=[checkpoint], verbose=1)
end = time.time()
print ("Model took %0.2f seconds to train"%(end - start))
# plot model history
plot_model_history(model_info)
# compute test accuracy
print ("Accuracy on test data is: %0.2f"%accuracy(test_features, test_labels, model))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
#   app.launch_new_instance()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras_pre..., validation_data=(array([[[..., callbacks=[<keras.ca..., verbose=1, steps_per_epoch=390, epochs=10)`
#   app.launch_new_instance()
# W0629 19:21:15.977704 139716608444288 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Epoch 1/10
# 390/390 [==============================] - 24s 61ms/step - loss: 1.5332 - acc: 0.4600 - val_loss: 1.4697 - val_acc: 0.5104
#
# Epoch 00001: val_acc improved from -inf to 0.51040, saving model to Best_weights.hdf5
# Epoch 2/10
# 390/390 [==============================] - 17s 43ms/step - loss: 1.1922 - acc: 0.5929 - val_loss: 1.2792 - val_acc: 0.5645
#
# Epoch 00002: val_acc improved from 0.51040 to 0.56450, saving model to Best_weights.hdf5
# Epoch 3/10
# 390/390 [==============================] - 16s 41ms/step - loss: 1.0622 - acc: 0.6428 - val_loss: 1.1764 - val_acc: 0.6227
#
# Epoch 00003: val_acc improved from 0.56450 to 0.62270, saving model to Best_weights.hdf5
# Epoch 4/10
# 390/390 [==============================] - 16s 40ms/step - loss: 0.9812 - acc: 0.6752 - val_loss: 1.0824 - val_acc: 0.6514
#
# Epoch 00004: val_acc improved from 0.62270 to 0.65140, saving model to Best_weights.hdf5
# Epoch 5/10
# 390/390 [==============================] - 16s 40ms/step - loss: 0.9095 - acc: 0.7028 - val_loss: 1.0018 - val_acc: 0.6768
#
# Epoch 00005: val_acc improved from 0.65140 to 0.67680, saving model to Best_weights.hdf5
# Epoch 6/10
# 390/390 [==============================] - 16s 40ms/step - loss: 0.8614 - acc: 0.7262 - val_loss: 0.8378 - val_acc: 0.7302
#
# Epoch 00006: val_acc improved from 0.67680 to 0.73020, saving model to Best_weights.hdf5
# Epoch 7/10
# 390/390 [==============================] - 16s 40ms/step - loss: 0.8180 - acc: 0.7434 - val_loss: 0.7150 - val_acc: 0.7802
#
# Epoch 00007: val_acc improved from 0.73020 to 0.78020, saving model to Best_weights.hdf5
# Epoch 8/10
# 390/390 [==============================] - 16s 40ms/step - loss: 0.7928 - acc: 0.7527 - val_loss: 0.7483 - val_acc: 0.7730
#
# Epoch 00008: val_acc did not improve from 0.78020
# Epoch 9/10
# 390/390 [==============================] - 16s 40ms/step - loss: 0.7704 - acc: 0.7631 - val_loss: 0.6873 - val_acc: 0.7930
#
# Epoch 00009: val_acc improved from 0.78020 to 0.79300, saving model to Best_weights.hdf5
# Epoch 10/10
# 390/390 [==============================] - 16s 40ms/step - loss: 0.7535 - acc: 0.7727 - val_loss: 0.9960 - val_acc: 0.7080
#
# Epoch 00010: val_acc did not improve from 0.79300
# Model took 170.10 seconds to train
# Accuracy on test data is: 70.80

# %% [markdown]
# ### We can observe that the gap between training and validation loss and accuracy also has reduced a lot from before .
# ### 1)Also we can find that each epoch takes lesser time
# ### 2) Reduces overfitting as before and improving regularization
# ### 3) Accuracy improved from 86.34 to 86.75

# %%
# train the model
start = time.time()
# Train the model
model_info = model.fit_generator(datagen.flow(train_features, train_labels, batch_size = 128),
                                 samples_per_epoch = train_features.shape[0], nb_epoch = 90, 
                                 validation_data = (test_features, test_labels),callbacks=[checkpoint], verbose=1)
end = time.time()
print ("Model took %0.2f seconds to train"%(end - start))
# plot model history
plot_model_history(model_info)
# compute test accuracy
print ("Accuracy on test data is: %0.2f"%accuracy(test_features, test_labels, model))
# Out:
# Epoch 1/90
#   3/390 [..............................] - ETA: 19s - loss: 0.7267 - acc: 0.7969
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
#   """
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras_pre..., validation_data=(array([[[..., callbacks=[<keras.ca..., verbose=1, steps_per_epoch=390, epochs=90)`
#   """
# 390/390 [==============================] - 16s 40ms/step - loss: 0.7362 - acc: 0.7779 - val_loss: 0.8667 - val_acc: 0.7444
#
# Epoch 00001: val_acc did not improve from 0.79300
# Epoch 2/90
# 390/390 [==============================] - 16s 41ms/step - loss: 0.7278 - acc: 0.7846 - val_loss: 0.8127 - val_acc: 0.7660
#
# Epoch 00002: val_acc did not improve from 0.79300
# Epoch 3/90
# 390/390 [==============================] - 16s 41ms/step - loss: 0.7121 - acc: 0.7899 - val_loss: 0.7063 - val_acc: 0.7995
#
# Epoch 00003: val_acc improved from 0.79300 to 0.79950, saving model to Best_weights.hdf5
# Epoch 4/90
# 390/390 [==============================] - 16s 41ms/step - loss: 0.7025 - acc: 0.7947 - val_loss: 0.7209 - val_acc: 0.7937
#
# Epoch 00004: val_acc did not improve from 0.79950
# Epoch 5/90
# 390/390 [==============================] - 16s 40ms/step - loss: 0.6936 - acc: 0.7978 - val_loss: 0.7316 - val_acc: 0.7897
#
# Epoch 00005: val_acc did not improve from 0.79950
# Epoch 6/90
# 390/390 [==============================] - 16s 40ms/step - loss: 0.6830 - acc: 0.8047 - val_loss: 0.6569 - val_acc: 0.8205
#
# Epoch 00006: val_acc improved from 0.79950 to 0.82050, saving model to Best_weights.hdf5
# Epoch 7/90
# 390/390 [==============================] - 16s 40ms/step - loss: 0.6750 - acc: 0.8084 - val_loss: 0.6787 - val_acc: 0.8151
#
# Epoch 00007: val_acc did not improve from 0.82050
# Epoch 8/90
# 390/390 [==============================] - 16s 40ms/step - loss: 0.6773 - acc: 0.8064 - val_loss: 0.7109 - val_acc: 0.7999
#
# Epoch 00008: val_acc did not improve from 0.82050
# Epoch 9/90
# 390/390 [==============================] - 16s 40ms/step - loss: 0.6595 - acc: 0.8147 - val_loss: 0.6973 - val_acc: 0.8049
#
# Epoch 00009: val_acc did not improve from 0.82050
# Epoch 10/90
# 390/390 [==============================] - 16s 40ms/step - loss: 0.6584 - acc: 0.8159 - val_loss: 0.9407 - val_acc: 0.7355
#
# Epoch 00010: val_acc did not improve from 0.82050
# Epoch 11/90
# 390/390 [==============================] - 16s 40ms/step - loss: 0.6477 - acc: 0.8214 - val_loss: 0.6608 - val_acc: 0.8228
#
# Epoch 00011: val_acc improved from 0.82050 to 0.82280, saving model to Best_weights.hdf5
# Epoch 12/90
# 390/390 [==============================] - 16s 40ms/step - loss: 0.6458 - acc: 0.8213 - val_loss: 0.6156 - val_acc: 0.8403
#
# Epoch 00012: val_acc improved from 0.82280 to 0.84030, saving model to Best_weights.hdf5
# Epoch 13/90
# 390/390 [==============================] - 16s 40ms/step - loss: 0.6350 - acc: 0.8267 - val_loss: 0.6462 - val_acc: 0.8303
#
# Epoch 00013: val_acc did not improve from 0.84030
# Epoch 14/90
# 390/390 [==============================] - 16s 40ms/step - loss: 0.6383 - acc: 0.8259 - val_loss: 0.6497 - val_acc: 0.8287
#
# Epoch 00014: val_acc did not improve from 0.84030
# Epoch 15/90
# 390/390 [==============================] - 16s 40ms/step - loss: 0.6389 - acc: 0.8254 - val_loss: 0.7074 - val_acc: 0.8102
#
# Epoch 00015: val_acc did not improve from 0.84030
# Epoch 16/90
# 390/390 [==============================] - 16s 40ms/step - loss: 0.6256 - acc: 0.8302 - val_loss: 0.6924 - val_acc: 0.8149
#
# Epoch 00016: val_acc did not improve from 0.84030
# Epoch 17/90
# 390/390 [==============================] - 16s 40ms/step - loss: 0.6261 - acc: 0.8330 - val_loss: 0.6483 - val_acc: 0.8254
#
# Epoch 00017: val_acc did not improve from 0.84030
# Epoch 18/90
# 390/390 [==============================] - 16s 40ms/step - loss: 0.6269 - acc: 0.8320 - val_loss: 0.6489 - val_acc: 0.8290
#
# Epoch 00018: val_acc did not improve from 0.84030
# Epoch 19/90
# 390/390 [==============================] - 16s 40ms/step - loss: 0.6191 - acc: 0.8357 - val_loss: 0.5971 - val_acc: 0.8494
#
# Epoch 00019: val_acc improved from 0.84030 to 0.84940, saving model to Best_weights.hdf5
# Epoch 20/90
# 390/390 [==============================] - 16s 40ms/step - loss: 0.6262 - acc: 0.8324 - val_loss: 0.6532 - val_acc: 0.8292
#
# Epoch 00020: val_acc did not improve from 0.84940
# Epoch 21/90
# 390/390 [==============================] - 16s 40ms/step - loss: 0.6174 - acc: 0.8363 - val_loss: 0.5990 - val_acc: 0.8491
#
# Epoch 00021: val_acc did not improve from 0.84940
# Epoch 22/90
# 390/390 [==============================] - 16s 40ms/step - loss: 0.6084 - acc: 0.8412 - val_loss: 0.6619 - val_acc: 0.8307
#
# Epoch 00022: val_acc did not improve from 0.84940
# Epoch 23/90
# 390/390 [==============================] - 16s 40ms/step - loss: 0.6133 - acc: 0.8396 - val_loss: 0.6702 - val_acc: 0.8187
#
# Epoch 00023: val_acc did not improve from 0.84940
# Epoch 24/90
# 390/390 [==============================] - 16s 40ms/step - loss: 0.6045 - acc: 0.8426 - val_loss: 0.6671 - val_acc: 0.8257
#
# Epoch 00024: val_acc did not improve from 0.84940
# Epoch 25/90
# 390/390 [==============================] - 16s 40ms/step - loss: 0.6028 - acc: 0.8421 - val_loss: 0.6244 - val_acc: 0.8399
#
# Epoch 00025: val_acc did not improve from 0.84940
# Epoch 26/90
# 390/390 [==============================] - 16s 40ms/step - loss: 0.6033 - acc: 0.8441 - val_loss: 0.6498 - val_acc: 0.8290
#
# Epoch 00026: val_acc did not improve from 0.84940
# Epoch 27/90
# 390/390 [==============================] - 16s 40ms/step - loss: 0.6013 - acc: 0.8447 - val_loss: 0.6292 - val_acc: 0.8419
#
# Epoch 00027: val_acc did not improve from 0.84940
# Epoch 28/90
# 390/390 [==============================] - 15s 40ms/step - loss: 0.6024 - acc: 0.8444 - val_loss: 0.6499 - val_acc: 0.8333
#
# Epoch 00028: val_acc did not improve from 0.84940
# Epoch 29/90
# 390/390 [==============================] - 16s 40ms/step - loss: 0.5982 - acc: 0.8448 - val_loss: 0.6023 - val_acc: 0.8498
#
# Epoch 00029: val_acc improved from 0.84940 to 0.84980, saving model to Best_weights.hdf5
# Epoch 30/90
# 390/390 [==============================] - 16s 40ms/step - loss: 0.5998 - acc: 0.8464 - val_loss: 0.6495 - val_acc: 0.8392
#
# Epoch 00030: val_acc did not improve from 0.84980
# Epoch 31/90
# 390/390 [==============================] - 16s 40ms/step - loss: 0.5948 - acc: 0.8479 - val_loss: 0.6546 - val_acc: 0.8372
#
# Epoch 00031: val_acc did not improve from 0.84980
# Epoch 32/90
# 390/390 [==============================] - 16s 40ms/step - loss: 0.5988 - acc: 0.8492 - val_loss: 0.6711 - val_acc: 0.8325
#
# Epoch 00032: val_acc did not improve from 0.84980
# Epoch 33/90
# 390/390 [==============================] - 16s 40ms/step - loss: 0.5921 - acc: 0.8505 - val_loss: 0.6191 - val_acc: 0.8457
#
# Epoch 00033: val_acc did not improve from 0.84980
# Epoch 34/90
# 390/390 [==============================] - 16s 40ms/step - loss: 0.5913 - acc: 0.8499 - val_loss: 0.6085 - val_acc: 0.8510
#
# Epoch 00034: val_acc improved from 0.84980 to 0.85100, saving model to Best_weights.hdf5
# Epoch 35/90
# 390/390 [==============================] - 16s 40ms/step - loss: 0.5946 - acc: 0.8496 - val_loss: 0.6093 - val_acc: 0.8497
#
# Epoch 00035: val_acc did not improve from 0.85100
# Epoch 36/90
# 390/390 [==============================] - 16s 40ms/step - loss: 0.5903 - acc: 0.8516 - val_loss: 0.6185 - val_acc: 0.8478
#
# Epoch 00036: val_acc did not improve from 0.85100
# Epoch 37/90
# 390/390 [==============================] - 16s 40ms/step - loss: 0.5892 - acc: 0.8528 - val_loss: 0.6148 - val_acc: 0.8490
#
# Epoch 00037: val_acc did not improve from 0.85100
# Epoch 38/90
# 390/390 [==============================] - 16s 40ms/step - loss: 0.5804 - acc: 0.8556 - val_loss: 0.6265 - val_acc: 0.8471
#
# Epoch 00038: val_acc did not improve from 0.85100
# Epoch 39/90
# 390/390 [==============================] - 15s 40ms/step - loss: 0.5881 - acc: 0.8516 - val_loss: 0.6497 - val_acc: 0.8391
#
# Epoch 00039: val_acc did not improve from 0.85100
# Epoch 40/90
# 390/390 [==============================] - 16s 40ms/step - loss: 0.5864 - acc: 0.8534 - val_loss: 0.6054 - val_acc: 0.8529
#
# Epoch 00040: val_acc improved from 0.85100 to 0.85290, saving model to Best_weights.hdf5
# Epoch 41/90
# 390/390 [==============================] - 16s 40ms/step - loss: 0.5828 - acc: 0.8558 - val_loss: 0.6096 - val_acc: 0.8552
#
# Epoch 00041: val_acc improved from 0.85290 to 0.85520, saving model to Best_weights.hdf5
# Epoch 42/90
# 390/390 [==============================] - 16s 40ms/step - loss: 0.5868 - acc: 0.8527 - val_loss: 0.6089 - val_acc: 0.8517
#
# Epoch 00042: val_acc did not improve from 0.85520
# Epoch 43/90
# 390/390 [==============================] - 16s 40ms/step - loss: 0.5775 - acc: 0.8569 - val_loss: 0.6714 - val_acc: 0.8346
#
# Epoch 00043: val_acc did not improve from 0.85520
# Epoch 44/90
# 390/390 [==============================] - 16s 40ms/step - loss: 0.5768 - acc: 0.8565 - val_loss: 0.6457 - val_acc: 0.8408
#
# Epoch 00044: val_acc did not improve from 0.85520
# Epoch 45/90
# 390/390 [==============================] - 16s 40ms/step - loss: 0.5840 - acc: 0.8548 - val_loss: 0.6502 - val_acc: 0.8368
#
# Epoch 00045: val_acc did not improve from 0.85520
# Epoch 46/90
# 390/390 [==============================] - 16s 40ms/step - loss: 0.5735 - acc: 0.8606 - val_loss: 0.6080 - val_acc: 0.8541
#
# Epoch 00046: val_acc did not improve from 0.85520
# Epoch 47/90
# 390/390 [==============================] - 16s 40ms/step - loss: 0.5742 - acc: 0.8580 - val_loss: 0.6276 - val_acc: 0.8456
#
# Epoch 00047: val_acc did not improve from 0.85520
# Epoch 48/90
# 390/390 [==============================] - 16s 40ms/step - loss: 0.5768 - acc: 0.8591 - val_loss: 0.6297 - val_acc: 0.8450
#
# Epoch 00048: val_acc did not improve from 0.85520
# Epoch 49/90
# 390/390 [==============================] - 15s 40ms/step - loss: 0.5739 - acc: 0.8594 - val_loss: 0.6080 - val_acc: 0.8552
#
# Epoch 00049: val_acc did not improve from 0.85520
# Epoch 50/90
# 390/390 [==============================] - 16s 40ms/step - loss: 0.5717 - acc: 0.8590 - val_loss: 0.6192 - val_acc: 0.8503
#
# Epoch 00050: val_acc did not improve from 0.85520
# Epoch 51/90
# 390/390 [==============================] - 16s 40ms/step - loss: 0.5711 - acc: 0.8593 - val_loss: 0.6336 - val_acc: 0.8473
#
# Epoch 00051: val_acc did not improve from 0.85520
# Epoch 52/90
# 390/390 [==============================] - 16s 40ms/step - loss: 0.5748 - acc: 0.8601 - val_loss: 0.6906 - val_acc: 0.8286
#
# Epoch 00052: val_acc did not improve from 0.85520
# Epoch 53/90
# 390/390 [==============================] - 16s 40ms/step - loss: 0.5721 - acc: 0.8607 - val_loss: 0.6632 - val_acc: 0.8341
#
# Epoch 00053: val_acc did not improve from 0.85520
# Epoch 54/90
# 390/390 [==============================] - 16s 40ms/step - loss: 0.5685 - acc: 0.8615 - val_loss: 0.6630 - val_acc: 0.8371
#
# Epoch 00054: val_acc did not improve from 0.85520
# Epoch 55/90
# 390/390 [==============================] - 16s 40ms/step - loss: 0.5680 - acc: 0.8636 - val_loss: 0.6740 - val_acc: 0.8355
#
# Epoch 00055: val_acc did not improve from 0.85520
# Epoch 56/90
# 390/390 [==============================] - 16s 40ms/step - loss: 0.5617 - acc: 0.8643 - val_loss: 0.6105 - val_acc: 0.8527
#
# Epoch 00056: val_acc did not improve from 0.85520
# Epoch 57/90
# 390/390 [==============================] - 16s 40ms/step - loss: 0.5753 - acc: 0.8587 - val_loss: 0.5958 - val_acc: 0.8581
#
# Epoch 00057: val_acc improved from 0.85520 to 0.85810, saving model to Best_weights.hdf5
# Epoch 58/90
# 390/390 [==============================] - 15s 40ms/step - loss: 0.5658 - acc: 0.8640 - val_loss: 0.6621 - val_acc: 0.8385
#
# Epoch 00058: val_acc did not improve from 0.85810
# Epoch 59/90
# 390/390 [==============================] - 15s 40ms/step - loss: 0.5676 - acc: 0.8626 - val_loss: 0.6354 - val_acc: 0.8445
#
# Epoch 00059: val_acc did not improve from 0.85810
# Epoch 60/90
# 390/390 [==============================] - 16s 40ms/step - loss: 0.5645 - acc: 0.8635 - val_loss: 0.5981 - val_acc: 0.8583
#
# Epoch 00060: val_acc improved from 0.85810 to 0.85830, saving model to Best_weights.hdf5
# Epoch 61/90
# 390/390 [==============================] - 16s 40ms/step - loss: 0.5651 - acc: 0.8648 - val_loss: 0.6852 - val_acc: 0.8350
#
# Epoch 00061: val_acc did not improve from 0.85830
# Epoch 62/90
# 390/390 [==============================] - 16s 40ms/step - loss: 0.5690 - acc: 0.8621 - val_loss: 0.6263 - val_acc: 0.8490
#
# Epoch 00062: val_acc did not improve from 0.85830
# Epoch 63/90
# 390/390 [==============================] - 16s 40ms/step - loss: 0.5656 - acc: 0.8624 - val_loss: 0.6944 - val_acc: 0.8293
#
# Epoch 00063: val_acc did not improve from 0.85830
# Epoch 64/90
# 390/390 [==============================] - 15s 39ms/step - loss: 0.5622 - acc: 0.8627 - val_loss: 0.5881 - val_acc: 0.8634
#
# Epoch 00064: val_acc improved from 0.85830 to 0.86340, saving model to Best_weights.hdf5
# Epoch 65/90
# 390/390 [==============================] - 16s 40ms/step - loss: 0.5635 - acc: 0.8636 - val_loss: 0.6082 - val_acc: 0.8557
#
# Epoch 00065: val_acc did not improve from 0.86340
# Epoch 66/90
# 390/390 [==============================] - 16s 40ms/step - loss: 0.5556 - acc: 0.8686 - val_loss: 0.5997 - val_acc: 0.8628
#
# Epoch 00066: val_acc did not improve from 0.86340
# Epoch 67/90
# 390/390 [==============================] - 15s 40ms/step - loss: 0.5673 - acc: 0.8635 - val_loss: 0.6321 - val_acc: 0.8474
#
# Epoch 00067: val_acc did not improve from 0.86340
# Epoch 68/90
# 390/390 [==============================] - 16s 40ms/step - loss: 0.5621 - acc: 0.8643 - val_loss: 0.5974 - val_acc: 0.8629
#
# Epoch 00068: val_acc did not improve from 0.86340
# Epoch 69/90
# 390/390 [==============================] - 16s 40ms/step - loss: 0.5549 - acc: 0.8683 - val_loss: 0.6346 - val_acc: 0.8508
#
# Epoch 00069: val_acc did not improve from 0.86340
# Epoch 70/90
# 390/390 [==============================] - 16s 40ms/step - loss: 0.5661 - acc: 0.8654 - val_loss: 0.6060 - val_acc: 0.8599
#
# Epoch 00070: val_acc did not improve from 0.86340
# Epoch 71/90
# 390/390 [==============================] - 15s 40ms/step - loss: 0.5604 - acc: 0.8662 - val_loss: 0.6660 - val_acc: 0.8420
#
# Epoch 00071: val_acc did not improve from 0.86340
# Epoch 72/90
# 390/390 [==============================] - 16s 40ms/step - loss: 0.5594 - acc: 0.8678 - val_loss: 0.7424 - val_acc: 0.8181
#
# Epoch 00072: val_acc did not improve from 0.86340
# Epoch 73/90
# 390/390 [==============================] - 15s 40ms/step - loss: 0.5587 - acc: 0.8672 - val_loss: 0.6494 - val_acc: 0.8435
#
# Epoch 00073: val_acc did not improve from 0.86340
# Epoch 74/90
# 390/390 [==============================] - 16s 40ms/step - loss: 0.5548 - acc: 0.8706 - val_loss: 0.6344 - val_acc: 0.8488
#
# Epoch 00074: val_acc did not improve from 0.86340
# Epoch 75/90
# 390/390 [==============================] - 15s 40ms/step - loss: 0.5624 - acc: 0.8651 - val_loss: 0.6729 - val_acc: 0.8363
#
# Epoch 00075: val_acc did not improve from 0.86340
# Epoch 76/90
# 390/390 [==============================] - 16s 40ms/step - loss: 0.5534 - acc: 0.8696 - val_loss: 0.6097 - val_acc: 0.8567
#
# Epoch 00076: val_acc did not improve from 0.86340
# Epoch 77/90
# 390/390 [==============================] - 15s 40ms/step - loss: 0.5590 - acc: 0.8675 - val_loss: 0.6657 - val_acc: 0.8391
#
# Epoch 00077: val_acc did not improve from 0.86340
# Epoch 78/90
# 390/390 [==============================] - 16s 40ms/step - loss: 0.5556 - acc: 0.8689 - val_loss: 0.5933 - val_acc: 0.8675
#
# Epoch 00078: val_acc improved from 0.86340 to 0.86750, saving model to Best_weights.hdf5
# Epoch 79/90
# 390/390 [==============================] - 16s 40ms/step - loss: 0.5534 - acc: 0.8690 - val_loss: 0.6573 - val_acc: 0.8449
#
# Epoch 00079: val_acc did not improve from 0.86750
# Epoch 80/90
# 390/390 [==============================] - 16s 40ms/step - loss: 0.5498 - acc: 0.8705 - val_loss: 0.6272 - val_acc: 0.8533
#
# Epoch 00080: val_acc did not improve from 0.86750
# Epoch 81/90
# 390/390 [==============================] - 16s 40ms/step - loss: 0.5550 - acc: 0.8705 - val_loss: 0.6229 - val_acc: 0.8559
#
# Epoch 00081: val_acc did not improve from 0.86750
# Epoch 82/90
# 390/390 [==============================] - 16s 40ms/step - loss: 0.5567 - acc: 0.8703 - val_loss: 0.6745 - val_acc: 0.8382
#
# Epoch 00082: val_acc did not improve from 0.86750
# Epoch 83/90
# 390/390 [==============================] - 16s 40ms/step - loss: 0.5488 - acc: 0.8732 - val_loss: 0.6857 - val_acc: 0.8360
#
# Epoch 00083: val_acc did not improve from 0.86750
# Epoch 84/90
# 390/390 [==============================] - 15s 40ms/step - loss: 0.5512 - acc: 0.8722 - val_loss: 0.6524 - val_acc: 0.8442
#
# Epoch 00084: val_acc did not improve from 0.86750
# Epoch 85/90
# 390/390 [==============================] - 15s 40ms/step - loss: 0.5489 - acc: 0.8713 - val_loss: 0.6311 - val_acc: 0.8548
#
# Epoch 00085: val_acc did not improve from 0.86750
# Epoch 86/90
# 390/390 [==============================] - 15s 39ms/step - loss: 0.5541 - acc: 0.8682 - val_loss: 0.6319 - val_acc: 0.8483
#
# Epoch 00086: val_acc did not improve from 0.86750
# Epoch 87/90
# 390/390 [==============================] - 16s 40ms/step - loss: 0.5487 - acc: 0.8715 - val_loss: 0.6158 - val_acc: 0.8524
#
# Epoch 00087: val_acc did not improve from 0.86750
# Epoch 88/90
# 390/390 [==============================] - 15s 40ms/step - loss: 0.5490 - acc: 0.8736 - val_loss: 0.6249 - val_acc: 0.8585
#
# Epoch 00088: val_acc did not improve from 0.86750
# Epoch 89/90
# 390/390 [==============================] - 16s 40ms/step - loss: 0.5503 - acc: 0.8725 - val_loss: 0.6621 - val_acc: 0.8430
#
# Epoch 00089: val_acc did not improve from 0.86750
# Epoch 90/90
# 390/390 [==============================] - 15s 40ms/step - loss: 0.5489 - acc: 0.8727 - val_loss: 0.6103 - val_acc: 0.8623
#
# Epoch 00090: val_acc did not improve from 0.86750
# Model took 1403.07 seconds to train
# Accuracy on test data is: 86.23

# %%
import cv2
show_gradcam(test_features[1001],layer_name='conv2d_5')
# Out:
# airplane

# %%
show_gradcam(test_features[1101],layer_name='conv2d_5')
# Out:
# ship

# %%
show_gradcam(test_features[1111],layer_name='conv2d_5')
# Out:
# ship

# %%
show_gradcam(test_features[99],layer_name='conv2d_5')
# Out:
# horse

# %%
show_gradcam(test_features[8010],layer_name='conv2d_5')
# Out:
# bird

# %% [markdown]
# ## We see that comapring the previous results without cut-out gradcam performs better here ,The focus (activations ) on the obvious parts of the objects is much more precise
